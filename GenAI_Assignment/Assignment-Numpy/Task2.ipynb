# %%
import numpy as np

# %%
A = np.array([10,20,30,40])

B = np.array([1,2,3,4])

# %%
print("Addition:", A+B)
# Out:
# Addition: [11 22 33 44]

# %%
print("Subtraction:", A-B)
# Out:
# Subtraction: [ 9 18 27 36]

# %%
print("Multipllication:", A*B)
# Out:
# Multipllication: [ 10  40  90 160]

# %%
print("Division:", A/B)
# Out:
# Division: [10. 10. 10. 10.]

# %%
print("Power:",A**2)
# Out:
# Power: [ 100  400  900 1600]
