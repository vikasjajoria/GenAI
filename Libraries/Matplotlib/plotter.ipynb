# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Pandas/Student_Depression_Dataset.csv")

# %%
df.head(10)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
# 5  33    Male  29.0           Pune    Student                2.0
# 6  52    Male  30.0          Thane    Student                3.0
# 7  56  Female  30.0        Chennai    Student                2.0
# 8  59    Male  28.0         Nagpur    Student                3.0
# 9  62    Male  31.0         Nashik    Student                2.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# ...

# %%
data=df['Gender'].value_counts()

# %%
data
# Out:
# Gender
# Male      15547
# Female    12354
# Name: count, dtype: int64

# %%
x=data.index
y=data.values

# %% [markdown]
# ## bar()   plt.bar()

# %%
plt.figure(figsize=(8,4))
plt.title('Univariate Analysis on gender column')
plt.xlabel('')
plt.xlabel('Gender')
plt.bar(x,y)
plt.show()

# %%
df.head(5)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df['Dietary Habits'].value_counts()
# Out:
# Dietary Habits
# Unhealthy    10317
# Moderate      9921
# Healthy       7651
# Others          12
# Name: count, dtype: int64

# %%
df=df[(df['Dietary Habits'] == 'Unhealthy') | (df['Dietary Habits']== 'Moderate')]

# %%
df['Dietary Habits'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Dietary Habits'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      11512
# Female     8726
# Name: count, dtype: int64

# %%
male=df[df['Gender']=='Male'].head(11512)

# %%
female=df[df['Gender']=='Female']

# %%
female.head()
# Out:
#      id  Gender   Age       City Profession  Academic Pressure  Work Pressure  \
# 1     8  Female  24.0  Bangalore    Student                2.0            0.0
# 3    30  Female  28.0   Varanasi    Student                3.0            0.0
# 4    32  Female  25.0     Jaipur    Student                4.0            0.0
# 7    56  Female  30.0    Chennai    Student                2.0            0.0
# 13  100  Female  19.0     Rajkot    Student                2.0            0.0
#
#     CGPA  Study Satisfaction  Job Satisfaction     Sleep Duration  \
# 1   5.90                 5.0               0.0          5-6 hours
# 3   5.59                 2.0               0.0          7-8 hours
# 4   8.13                 3.0               0.0          5-6 hours
# 7   8.04                 4.0               0.0  Less than 5 hours
# 13  8.52                 4.0               0.0  Less than 5 hours
#
#    Dietary Habits    Degree Have you ever had suicidal thoughts ?  \
# ...

# %% [markdown]
# ## concat() join two dataset

# %%
df=pd.concat([male,female])

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      11512
# Female     8726
# Name: count, dtype: int64

# %%
data=df.groupby('Gender')['Academic Pressure'].sum()

# %%
data
# Out:
# Gender
# Female    28251.0
# Male      36444.0
# Name: Academic Pressure, dtype: float64

# %%
x=data.index
y=data.values

# %%
plt.bar(x,y)
plt.show()

# %%
sales=pd.read_csv('Chocolate Sales.csv')

# %%
sales
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# ## country based total sales

# %%
data=sales.groupby('Country')['Amount'].sum()

# %%
data
# Out:
# Country
# Australia      1137367
# Canada          962899
# India          1045800
# New Zealand     950418
# UK             1051792
# USA            1035349
# Name: Amount, dtype: int64

# %%
x=data.index
y=data.values

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
sales['Product'].value_counts().head(7)
# Out:
# Product
# 50% Dark Bites         60
# Eclairs                60
# Smooth Sliky Salty     59
# White Choc             58
# Drinking Coco          56
# Spicy Special Slims    54
# Organic Choco Syrup    52
# Name: count, dtype: int64

# %%
data=sales[(sales['Product']=='50% Dark Bites') | (sales['Product']=='Eclairs') | (sales['Product']=='Smooth Sliky Salty') | (sales['Product']=='White Choc') |(sales['Product']=='Drinking Coco') | (sales['Product']=='Spicy Special Syrup') | (sales['Product']=='Organic Choco Syrup')]

# %%
data['Product'].value_counts()
# Out:
# Product
# 50% Dark Bites         60
# Eclairs                60
# Smooth Sliky Salty     59
# White Choc             58
# Drinking Coco          56
# Organic Choco Syrup    52
# Name: count, dtype: int64

# %%
d=data.groupby('Product')['Boxes Shipped'].sum()

# %%
d
# Out:
# Product
# 50% Dark Bites         9792
# Drinking Coco          8660
# Eclairs                8757
# Organic Choco Syrup    7749
# Smooth Sliky Salty     8810
# White Choc             8240
# Name: Boxes Shipped, dtype: int64

# %%
x=d.index
y=d.values

# %%
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Horizontal bar chart

# %%
df
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 8          59    Male  28.0     Nagpur    Student                3.0
# 9          62    Male  31.0     Nashik    Student                2.0
# 10         83    Male  24.0     Nagpur    Student                3.0
# 12         94    Male  27.0     Kalyan    Student                5.0
# 15        106    Male  29.0   Srinagar    Student                3.0
# ...       ...     ...   ...        ...        ...                ...
# 27886  140601  Female  22.0     Jaipur    Student                5.0
# 27891  140645  Female  28.0      Thane    Student                4.0
# 27892  140669  Female  20.0     Indore    Student                3.0
# 27893  140672  Female  24.0  Hyderabad    Student                3.0
# 27896  140685  Female  27.0      Surat    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 8                0.0  9.79                 1.0               0.0
# ...

# %%
sales
# Out:
#           Sales Person    Country              Product       Date  Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22    5320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22    7896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22    4501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22   12726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22   13685
# ...                ...        ...                  ...        ...     ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22    4410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22    6559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22    2086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22    5075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %%
plt.barh(x,y)
plt.show()

# %%
sales.head()
# Out:
#      Sales Person    Country              Product       Date  Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22    5320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22    7896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22    4501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22   12726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22   13685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
m = sales[sales['Product'] == 'Mint Chip Choco']

m = m.groupby(m['Date'].dt.strftime('%B'))['Amount'].sum()

m
# Out:
# Date
# April       13160
# August      32718
# February    63518
# January     49525
# July        27783
# June        34293
# March       33467
# May         29505
# Name: Amount, dtype: int64

# %%
    plt.bar(m.index, m.values)
    plt.legend()
    plt.show()
# Out:
# C:\Users\vicky\AppData\Local\Temp\ipykernel_12780\1076317238.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
