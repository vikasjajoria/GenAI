# %% [markdown]
# Statistical functions

# %% [markdown]
# mean

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 3.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.8/12.6 MB 3.5 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.6 MB 3.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.6 MB 3.9 MB/s eta 0:00:03
#    -------------- ------------------------- 4.7/12.6 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.6 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/12.6 MB 4.0 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.6 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.6 MB 3.8 MB/s eta 0:00:02
#    --------------------------- ------------ 8.7/12.6 MB 3.9 MB/s eta 0:00:02
# ...

# %%
import numpy as np
array_data = np.round(np.random.random((4,4))*100).astype('int32')

# %%
array_data
# Out:
# array([[51, 95, 26, 66],
#        [78, 69, 58, 20],
#        [82, 93, 27, 82],
#        [91, 88, 48, 66]], dtype=int32)

# %%
np.max(array_data,axis=0)
# Out:
# array([91, 95, 58, 82], dtype=int32)

# %%
np.max(array_data,axis=1)
# Out:
# array([95, 78, 93, 91], dtype=int32)

# %%
np.prod(array_data,axis=1)
# Out:
# array([ 8314020,  6243120, 16883964, 25369344])

# %% [markdown]
# mean

# %%
array_data
# Out:
# array([[51, 95, 26, 66],
#        [78, 69, 58, 20],
#        [82, 93, 27, 82],
#        [91, 88, 48, 66]], dtype=int32)

# %%
np.mean(array_data)
# Out:
# np.float64(65.0)

# %%
np.mean(array_data,axis=1)
# Out:
# array([59.5 , 56.25, 71.  , 73.25])

# %%
np.mean(array_data,axis=0)
# Out:
# array([75.5 , 86.25, 39.75, 58.5 ])

# %% [markdown]
# std()

# %%
array_data
# Out:
# array([[51, 95, 26, 66],
#        [78, 69, 58, 20],
#        [82, 93, 27, 82],
#        [91, 88, 48, 66]], dtype=int32)

# %%
np.std(array_data)
# Out:
# np.float64(23.950469723994978)

# %% [markdown]
# Median

# %%
np.median(array_data,axis=1)
# Out:
# array([58.5, 63.5, 82. , 77. ])

# %%
np.median(array_data)
# Out:
# np.float64(67.5)

# %% [markdown]
# var()===variance

# %%
np.var(array_data)
# Out:
# np.float64(573.625)
