# %% [markdown]
# ## sum()

# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

# %%
data=pd.read_csv("youtube-videos.csv")

# %%
data
# Out:
#      rank                                              Video    Video views  \
# 0       1  20 Tennis shots if they were not filmed, NOBOD...      3,471,237
# 1       2  Lil Nas X - Old Town Road (Official Movie) ft....     54,071,677
# 2       3                 JoJo Siwa - Karma (Official Video)     34,206,747
# 3       4  Wiz Khalifa - See You Again ft. Charlie Puth [...  6,643,904,918
# 4       5                       伊賀の天然水強炭酸水「家族で、シュワシェア。」篇　15秒    236,085,971
# ..    ...                                                ...            ...
# 995   996  CALIFORNIA - MONDAY JUSTICE FEAT. SNOOP DOGG (...        943,248
# 996   997  John McEnroe's most famous outburst happened i...      4,853,621
# 997   998                         Adi Golan's Group - Teaser         56,578
# 998   999                   Keg tapping goes horribly wrong.        751,804
# 999  1000  LIVE Hurricane Irma - Downtown Orlando - Ameri...        554,438
#
#           Likes Dislikes         Category  published
# ...

# %%
subs=data['Video views']

# %%
subs
# Out:
# 0          3,471,237
# 1         54,071,677
# 2         34,206,747
# 3      6,643,904,918
# 4        236,085,971
#            ...
# 995          943,248
# 996        4,853,621
# 997           56,578
# 998          751,804
# 999          554,438
# Name: Video views, Length: 1000, dtype: str

# %%
subs.sum()
# Out:
# '3,471,23754,071,67734,206,7476,643,904,918236,085,97176,834,49518,558,39096,6869,605,9698,353,3188,718,3267,396,1997,958,18114,612,15313,894,90537,460,2968,286,09613,764,0986,953,8388,414,6765,851,41110,627,79798,468,5368,322,488699,38211,638,2015,756,53511,894,0765,923,0171,097,393,69559,857,48955,113,25316,676,5604,386,5643,845,18628,181,2416,484,6223,873,12115,694,3175,272,4872,993,030,4995,856,94612,643,8417,010,73220,146,9245,353,676514,69421,786,7323,409,9063,102,7517,529,9273,777,9972,985,3005,038,8485,461,43239,407,67417,802,7478,066,4218,690,90010,748,28616,485,6062,692,74021,596,6233,305,68136,311,87513,591,2499,857,163204,78252,049,7054,669,5462,943,1591,018,7135,250,4586,040,4295,989,0585,938,41614,921,4374,929,4813,630,53417,275,25010,188,5902,663,55081,744,4579,884,00512,255,4562,960,4938,393,2452,279,8336,016,6572,113,438148,996,97617,166,1296,587,4476,354,77168,224,9794,645,8154,485,52932,387,91810,779,0323,870,4512,638,35613,933,73561,892,7924,702,8702,472,0453,590,
# ...

# %%
subs.sort_values()
# Out:
# 638    1,001,605
# 627    1,006,860
# 388    1,009,282
# 700    1,012,866
# 816    1,015,248
#          ...
# 375      982,730
# 445      983,919
# 914      987,265
# 703      995,595
# 693      999,009
# Name: Video views, Length: 1000, dtype: str

# %%
print(subs.head())
print(subs.dtype)
# Out:
# 0        3,471,237
# 1       54,071,677
# 2       34,206,747
# 3    6,643,904,918
# 4      236,085,971
# Name: Video views, dtype: str
# str

# %%
subs.mean()
# Out:
# nan

# %%
subs.median()
# Out:
# np.float64(nan)

# %%
subs.mode()
# Out:
# Series([], Name: Video views, dtype: float64)

# %%
subs=data['Likes']

# %%
subs
# Out:
# 0          19,023
# 1       3,497,955
# 2         293,563
# 3      44,861,602
# 4              38
#           ...
# 995         2,949
# 996         7,254
# 997           NaN
# 998         3,427
# 999           184
# Name: Likes, Length: 1000, dtype: str

# %%
subs=pd.to_numeric(subs,errors="coerce")

# %%
print(subs.dtype)
# Out:
# float64

# %%
subs.mean()
# Out:
# np.float64(227.03061224489795)

# %%
subs.sum()
# Out:
# np.float64(66747.0)

# %%
subs.median()
# Out:
# np.float64(45.0)

# %%
subs.mode()
# Out:
# 0    2.0
# Name: Likes, dtype: float64

# %%
subs.describe()
# Out:
# count    294.000000
# mean     227.030612
# std      296.347704
# min        0.000000
# 25%        8.000000
# 50%       45.000000
# 75%      399.500000
# max      996.000000
# Name: Likes, dtype: float64

# %%
subs.std()
# Out:
# np.float64(296.34770374853593)

# %%
subs.var()
# Out:
# np.float64(87821.96151703001)

# %%
subs.max()
# Out:
# np.float64(996.0)

# %%
subs.min()
# Out:
# np.float64(0.0)

# %% [markdown]
# ## Indexing in Series

# %%
subs[2:12:2]
# Out:
# 2      NaN
# 4     38.0
# 6      NaN
# 8      6.0
# 10    46.0
# Name: Likes, dtype: float64

# %%
subs[::-1]
# Out:
# 999    184.0
# 998      NaN
# 997      NaN
# 996      NaN
# 995      NaN
#        ...
# 4       38.0
# 3        NaN
# 2        NaN
# 1        NaN
# 0        NaN
# Name: Likes, Length: 1000, dtype: float64

# %%
import pandas as pd

# %%
data=pd.read_csv("Libraries/Pandas/Student_Depression_Dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data=pd.read_csv("Libraries/Pandas/Student_Depression_Dataset.csv")
#
# File c:\GenAI\env\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...

# %%
data = pd.read_csv(r"C:/GenAI/Libraries/Pandas/Student_Depression_Dataset.csv")

# %%
data
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %% [markdown]
# ## filtiring

# %%
data.head(3)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours  Financial Stress  \
# 0                                   Yes               3.0               1.0
# 1                                    No               3.0               2.0
# ...

# %%
data[data['Financial Stress']==5]
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 3          30  Female  28.0   Varanasi    Student                3.0
# 9          62    Male  31.0     Nashik    Student                2.0
# 14        103  Female  19.0     Kalyan    Student                5.0
# 16        120    Male  25.0     Nashik    Student                5.0
# 22        166  Female  25.0  Ahmedabad    Student                3.0
# ...       ...     ...   ...        ...        ...                ...
# 27869  140512    Male  30.0  Hyderabad    Student                5.0
# 27874  140530  Female  19.0  Ghaziabad    Student                3.0
# 27883  140584  Female  22.0     Kanpur    Student                4.0
# 27891  140645  Female  28.0      Thane    Student                4.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
data.dtypes
# Out:
# id                                         int64
# Gender                                       str
# Age                                      float64
# City                                         str
# Profession                                   str
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                               str
# Dietary Habits                               str
# Degree                                       str
# Have you ever had suicidal thoughts ?        str
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness             str
# Depression                                 int64
# dtype: object

# %%
data.head(5)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.0    2258
# 20.0    2237
# 28.0    2133
# 29.0    1950
# 33.0    1893
# 25.0    1784
# 21.0    1726
# 23.0    1645
# 18.0    1587
# 19.0    1560
# 34.0    1468
# 27.0    1462
# 31.0    1427
# 32.0    1262
# 22.0    1160
# 26.0    1155
# 30.0    1145
# 35.0      10
# 38.0       8
# 36.0       7
# 42.0       4
# 39.0       3
# 48.0       3
# 43.0       2
# 46.0       2
# 37.0       2
# 58.0       1
# 49.0       1
# 51.0       1
# 44.0       1
# 59.0       1
# 54.0       1
# 56.0       1
# 41.0       1
# Name: count, dtype: int64

# %%
data['City'].value_counts()
# Out:
# City
# Kalyan                1570
# Srinagar              1372
# Hyderabad             1340
# Vasai-Virar           1290
# Lucknow               1155
# Thane                 1139
# Ludhiana              1111
# Agra                  1094
# Surat                 1078
# Kolkata               1066
# Jaipur                1036
# Patna                 1007
# Visakhapatnam          969
# Pune                   968
# Ahmedabad              951
# Bhopal                 934
# Chennai                885
# Meerut                 825
# Rajkot                 816
# Delhi                  768
# Bangalore              767
# Ghaziabad              745
# Mumbai                 699
# Vadodara               694
# Varanasi               685
# Nagpur                 651
# Indore                 643
# Kanpur                 609
# Nashik                 547
# Faridabad              461
# Saanvi                   2
# Bhavna                   2
# City                     2
# Harsha                   2
# ...

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      15547
# Female    12354
# Name: count, dtype: int64

# %%
data['Academic Pressure'].value_counts()
# Out:
# Academic Pressure
# 3.0    7462
# 5.0    6296
# 4.0    5155
# 1.0    4801
# 2.0    4178
# 0.0       9
# Name: count, dtype: int64

# %%
data['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# Less than 5 hours    8310
# 7-8 hours            7346
# 5-6 hours            6183
# More than 8 hours    6044
# Others                 18
# Name: count, dtype: int64

# %%
data['Profession'].value_counts()
# Out:
# Profession
# Student                   27870
# Architect                     8
# Teacher                       6
# Digital Marketer              3
# Content Writer                2
# Chef                          2
# Doctor                        2
# Pharmacist                    2
# Civil Engineer                1
# UX/UI Designer                1
# Educational Consultant        1
# Manager                       1
# Lawyer                        1
# Entrepreneur                  1
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# id                                         int64
# Gender                                       str
# Age                                      float64
# City                                         str
# Profession                                   str
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                               str
# Dietary Habits                               str
# Degree                                       str
# Have you ever had suicidal thoughts ?        str
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness             str
# Depression                                 int64
# dtype: object

# %%
data[(data['Profession']=='Teacher') & (data['Depression']==1)]
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 3841    19226   Male  31.0         Rajkot    Teacher                3.0
# 5016    25193   Male  24.0         Kalyan    Teacher                4.0
# 24121  121474   Male  27.0         Kalyan    Teacher                3.0
# 24482  123259   Male  23.0         Kanpur    Teacher                3.0
# 26289  132550   Male  25.0  Visakhapatnam    Teacher                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3841             0.0  7.48                 5.0               0.0
# 5016             0.0  9.66                 5.0               0.0
# 24121            0.0  5.89                 3.0               0.0
# 24482            0.0  5.59                 1.0               0.0
# 26289            0.0  7.25                 1.0               0.0
#
#           Sleep Duration Dietary Habits Degree  \
# 3841           5-6 hours      Unhealthy     MD
# ...

# %%
data[(data['Profession']=='Student') & (data['Age']==23) & (data['City']=='Pune') & (data['Gender']=='Male') & (data['Sleep Duration']=='5-6 hours') & (data['Degree']=='B.Tech')]
# Out:
#            id Gender   Age  City Profession  Academic Pressure  Work Pressure  \
# 4959    24869   Male  23.0  Pune    Student                3.0            0.0
# 19474   98661   Male  23.0  Pune    Student                3.0            0.0
# 25965  130855   Male  23.0  Pune    Student                4.0            0.0
#
#        CGPA  Study Satisfaction  Job Satisfaction Sleep Duration  \
# 4959   5.77                 4.0               0.0      5-6 hours
# 19474  9.21                 5.0               0.0      5-6 hours
# 25965  6.16                 3.0               0.0      5-6 hours
#
#       Dietary Habits  Degree Have you ever had suicidal thoughts ?  \
# 4959        Moderate  B.Tech                                   Yes
# 19474      Unhealthy  B.Tech                                   Yes
# 25965      Unhealthy  B.Tech                                   Yes
#
#        Work/Study Hours  Financial Stress Family History of Mental Illness  \
# ...

# %%
data.shape
# Out:
# (27901, 18)

# %%
data['Sleep Duration'].value_counts()
# Out:
# Sleep Duration
# Less than 5 hours    8310
# 7-8 hours            7346
# 5-6 hours            6183
# More than 8 hours    6044
# Others                 18
# Name: count, dtype: int64

# %%
data['Sleep Duration'].unique()
# Out:
# <StringArray>
# ['5-6 hours', 'Less than 5 hours', '7-8 hours', 'More than 8 hours', 'Others']
# Length: 5, dtype: str

# %% [markdown]
# ## Adding Columns

# %%
data['Name']='Vikas Kumar'

# %%
data.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  ...  \
# 0            0.0  8.97                 2.0               0.0  ...
# 1            0.0  5.90                 5.0               0.0  ...
# 2            0.0  7.03                 5.0               0.0  ...
# 3            0.0  5.59                 2.0               0.0  ...
# 4            0.0  8.13                 3.0               0.0  ...
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
# ...

# %%
data['Bio'] = data['Age'].astype(str) + " " + data['Gender']

# %%
data
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  ...  \
# ...

# %%
data.drop('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 data.drop('Name')
#
# File c:\GenAI\env\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File c:\GenAI\env\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# ...

# %%
data
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  str
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  str
#  4   Profession                             27901 non-null  str
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  str
# ...

# %%
data.drop(columns=['Name'], inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  str
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  str
#  4   Profession                             27901 non-null  str
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  str
# ...
