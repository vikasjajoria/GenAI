# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
pd.Series([60,40,50],index=['Bread','Milk','Butter'],name='Price of grocery items')
# Out:
# Bread     60
# Milk      40
# Butter    50
# Name: Price of grocery items, dtype: int64

# %%
country=['India','China','USA','Pakistan']

# %%
pd.Series(country)
# Out:
# 0       India
# 1       China
# 2         USA
# 3    Pakistan
# dtype: str

# %%
subject_names=['Maths','Physics','Chemistry','Biology','English']
subject_marks=[48,92,64,35,98]

# %%
pd.Series(data=subject_marks,index=subject_names)
# Out:
# Maths        48
# Physics      92
# Chemistry    64
# Biology      35
# English      98
# dtype: int64

# %% [markdown]
# ## creating an series using a numpy array

# %%
values=np.arange(10,21)
pd.Series(values)
# Out:
# 0     10
# 1     11
# 2     12
# 3     13
# 4     14
# 5     15
# 6     16
# 7     17
# 8     18
# 9     19
# 10    20
# dtype: int64

# %% [markdown]
# ## dictionary to series

# %%
data_items={'Maths':78,'English':92,'Physics':85,'Chemistry':75}
pd.Series(data_items)
# Out:
# Maths        78
# English      92
# Physics      85
# Chemistry    75
# dtype: int64

# %% [markdown]
# ## sacler value inside an series

# %%
pd.Series(4,index=['a','b','c','d','e'])
# Out:
# a    4
# b    4
# c    4
# d    4
# e    4
# dtype: int64

# %%
df=pd.read_csv("youtube-videos.csv")

# %%
df
# Out:
#      rank                                              Video    Video views  \
# 0       1  20 Tennis shots if they were not filmed, NOBOD...      3,471,237
# 1       2  Lil Nas X - Old Town Road (Official Movie) ft....     54,071,677
# 2       3                 JoJo Siwa - Karma (Official Video)     34,206,747
# 3       4  Wiz Khalifa - See You Again ft. Charlie Puth [...  6,643,904,918
# 4       5                       伊賀の天然水強炭酸水「家族で、シュワシェア。」篇　15秒    236,085,971
# ..    ...                                                ...            ...
# 995   996  CALIFORNIA - MONDAY JUSTICE FEAT. SNOOP DOGG (...        943,248
# 996   997  John McEnroe's most famous outburst happened i...      4,853,621
# 997   998                         Adi Golan's Group - Teaser         56,578
# 998   999                   Keg tapping goes horribly wrong.        751,804
# 999  1000  LIVE Hurricane Irma - Downtown Orlando - Ameri...        554,438
#
#           Likes Dislikes         Category  published
# ...

# %%
subs=df['Video views']

# %%
subs
# Out:
# 0          3,471,237
# 1         54,071,677
# 2         34,206,747
# 3      6,643,904,918
# 4        236,085,971
#            ...
# 995          943,248
# 996        4,853,621
# 997           56,578
# 998          751,804
# 999          554,438
# Name: Video views, Length: 1000, dtype: str

# %% [markdown]
# ### Mathematical Funcation
