# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('Titanic.csv',nrows=1000)

# %%
df['Age'].describe()
# Out:
# count    332.000000
# mean      30.272590
# std       14.181209
# min        0.170000
# 25%       21.000000
# 50%       27.000000
# 75%       39.000000
# max       76.000000
# Name: Age, dtype: float64

# %%
df[df['Age']==76]
# Out:
#     PassengerId  Survived  Pclass  \
# 96          988         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 96  Cavendish, Mrs. Tyrell William (Julia Florence...  female  76.0      1
#
#     Parch Ticket   Fare Cabin Embarked
# 96      0  19877  78.85   C46        S

# %%
sns.boxplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(86)

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Age'].describe()
# Out:
# count    418.000000
# mean      29.599282
# std       12.703770
# min        0.170000
# 25%       23.000000
# 50%       27.000000
# 75%       35.750000
# max       76.000000
# Name: Age, dtype: float64

# %%
sns.histplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df[df['Ticket']=='PC 17755']['Name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[df['Ticket']=='PC 17755']['Name']
#
# NameError: name 'df' is not defined

# %%
sns.boxlplot(data=df, x='Fair')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.boxlplot(data=df, x='Fair')
#
# AttributeError: module 'seaborn' has no attribute 'boxlplot'

# %%
df['Survived'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.scatterplot(data=df, x='Age', y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.barplot(data=df, x='Fare', y='Pclass')
# Out:
# <Axes: xlabel='Fare', ylabel='Pclass'>

# %%
sns.barplot(data=df, x='Embarked', y='Fare')
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: count, dtype: int64

# %%
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0   1
# Pclass
# 1          57  50
# 2          63  30
# 3         146  72

# %%
pd.crosstab(df['Sex'],df['Survived'])
# Out:
# Survived    0    1
# Sex
# female      0  152
# male      266    0

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64
