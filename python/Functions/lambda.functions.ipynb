# %% [markdown]
# Lambda functions

# %% [markdown]
# lambda functions are the one liner functions defined by the lambda keyword

# %%
lambda_function=lambda x:x**2

# %%
lambda_function(5)
# Out:
# 25

# %%
sum=lambda x,y:x+y
print(sum(5,6))
# Out:
# 11

# %%
product=lambda a,x,y,z:a*x*y*z
print(product(4,7,5,9))
# Out:
# 1260
