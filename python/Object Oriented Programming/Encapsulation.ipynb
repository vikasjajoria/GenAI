# %%
class Animal:

    def __init__(self,name,sound):
        self.name=name
        self.__sound=sound


    def sound_info(self):       #getter method
        print(f"The animal is going to sound as : {self.__sound}")  

    def sound_modify(self,new_sound):
        self.__sound=new_sound
        print(f"New sound for the animal is : {self.__sound}")

# %%
animal=Animal("Bruno","Woof Woof")

# %%
animal.name
# Out:
# 'Bruno'

# %%
#getter method
animal.sound_info()
# Out:
# The animal is going to sound as : meaw meaw

# %%
animal.sound_modify("meaw meaw")
# Out:
# New sound for the animal is : meaw meaw

# %%
class Grandparent:

    def __init__(self, name, locker_key):
        self.name = name
        self.__locker_key = locker_key

    # getter method
    def locker_info(self):
        print(f"The Locker key info is {self.__locker_key}")

# %%
class Parent(Grandparent):

    def __init__(self, name, locker_key):
        super().__init__(name, locker_key)

    def child_reveals(self):
        self.locker_info()

# %%
grandpa=Grandparent("Amit","12345")

# %%
grandpa.name
# Out:
# 'Amit'

# %%
grandpa.locker_info()
# Out:
# The Locker key info is 12345

# %%
parent=Parent("Vikas","12345")

# %%
parent.name
# Out:
# 'Vikas'

# %%
parent.locker_info()
# Out:
# The Locker key info is 12345

# %% [markdown]
# MA bank Account System

# %%
class BankAccount:

    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.__balance = balance

    def get_balance(self):
        return self.__balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            return "Amount deposited successfully"
        else:
            return "Amount must be positive"

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            return "Amount withdrawn successfully"
        else:
            return "Insufficient balance"

# %%
account = BankAccount("Amit", 10000)

# %%
account.get_balance()
# Out:
# 10000

# %%
account.withdraw(2000)
# Out:
# 'Amount withdrawn successfully'

# %%
account.get_balance()
# Out:
# 11000

# %%
account.deposit(3000)
# Out:
# 'Amount deposited successfully'

# %%
account.get_balance()
# Out:
# 11000

# %%
account.deposit(12300)
# Out:
# 'Amount deposited successfully'

# %%
account.get_balance()
# Out:
# 23300
