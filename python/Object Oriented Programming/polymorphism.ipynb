# %%
class Grandparent: 

    def speak(self):
        print("Hello my name is vikas")

class Parent(Grandparent):

    def speak(self):
        print("Hello My name is vikas junior")

class child(Grandparent):

    def speak(self):
        print("Hello my name is junior vikas junior")

# %%
def attribute_provider(objects):
    print(objects.speak())

# %%
Grandpa=Grandparent()

# %%
attribute_provider(Grandpa)
# Out:
# Hello my name is vikas
# None

# %%
class Shape:
    def area(self):
        return "This method returns the area of the shape"

# %%
class Rectangle(Shape):
    def __init__(self,width,height):
        self.width=width
        self.height=height

    def area(self):
        return self.width*self.height

# %%
class Circle(Shape):

    def __init__(self,radius):
        self.radius=radius

    def area(self):
        return 3.14*self.radius*self.radius

# %%
shape=Shape()
shape.area()
# Out:
# 'This method returns the area of the shape'

# %%
rectangle=Rectangle(6,4)
rectangle.area()
# Out:
# 24

# %%
circle=Circle(4)

# %%
circle.area()
# Out:
# 50.24
